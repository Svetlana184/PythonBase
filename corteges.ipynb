# %%
from random import randint
mas = (randint(1, 100) for i in range (randint(10, 21)))
for i in mas:
    print(i, end=" ")
# Out:
# 21 28 5 8 45 89 57 23 18 48 51 98 94 8 65 76 74 82 38

# %% [markdown]
# Задача 2

# %%
s = 0
for i in mas:
    s += i
print(s)
# Out:
# 0
