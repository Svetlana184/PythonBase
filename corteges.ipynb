# %%
from random import randint
mas = tuple(randint(1, 100) for i in range (randint(10, 21)))
for i in mas:
    print(i, end=" ")
# Out:
# 67 11 70 86 30 84 76 91 97 21 48 27 74 97

# %% [markdown]
# Задача 2

# %%
s = 0
for i in mas:
    s += i
print(s)
# Out:
# 879

# %% [markdown]
# Двумерные массивы

# %%
n,m = 5,6
matrix = tuple(tuple(randint(1, 100) for j in range (m)) for i in range (n))
summa_d = 0
for i in matrix:
    print(*i)
for i in range(len(matrix)):
    for j in range(len(matrix)):
        if i ==j:
            summa_d += matrix[i][j]
print("s = ", summa_d)
# Out:
# 51 14 8 69 84 96
# 91 92 19 3 62 32
# 87 26 86 16 77 43
# 25 99 37 65 15 48
# 37 36 82 31 72 37
# s=  366
